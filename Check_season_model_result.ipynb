# %%
team = {}
for gw in range(1, 39):
    team[gw] = {
        "line_up" : {},
        "bench" : [],
        "total_points" : 0
    }


with open("models/result.log", "r") as file:
    ready = False
    while not ready:
        text = file.readline()
        ready = "objective value:" in text
    objective_value = int(text.split(" ")[-1])
    
    ready = False
    while not ready:
        text = file.readline()
        if text == "\n":
            break
            
        variable, player = text.split("$")
        player, gw = player.split("#")
        gw = gw.split(" ")
        gw, obj = (int(gw[0]), gw[-1])
        obj = int(obj.split(":")[1].replace(")", ""))
        
        if variable == "player_on_team":
            team[gw]["bench"].append(player)
        elif variable == "player_on_lineup":
            team[gw]["bench"].remove(player)
            team[gw]["line_up"][player] = obj
            team[gw]["total_points"] += obj
        elif variable == "player_is_captain":
            obj += team[gw]["line_up"].pop(player)
            team[gw]["line_up"][f"{player} (C)"] = obj
            team[gw]["total_points"] += obj

team
# Out:
# {1: {'line_up': {'Sergi_Canos': 11,
#    'Ethan_Pinnock': 11,
#    'Marcos_Alonso': 15,
#    'Trevoh_Chalobah': 14,
#    'Dennis_Praet': 13,
#    'Kelechi_Iheanacho': 15,
#    'Wilfred_Ndidi': 16,
#    'Thiago_Alcantara_do_Nascimento': 11,
#    'Dean_Henderson': 12,
#    'Cristiano_Ronaldo_dos_Santos_Aveiro': 14,
#    'John_Stones (C)': 48},
#   'bench': ['Hector_Bellerin',
#    'Saman_Ghoddos',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 204},
#  2: {'line_up': {'Tyrone_Mings': 15,
#    'Shane_Duffy': 14,
#    'Vicente_Guaita': 9,
#    'Richarlison_de_Andrade': 11,
#    'Thiago_Alcantara_do_Nascimento': 11,
#    'HeungMin_Son': 13,
#    'Eric_Dier': 13,
#    'Craig_Cathcart': 10,
#    'Tomas_Soucek': 16,
#    'Pablo_Fornals': 13,
#    'Reece_James (C)': 36},
#   'bench': ['Edward_Nketiah', 'Saman_Ghoddos', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 179},
#  3: {'line_up': {'James_Maddison': 13,
#    'Kelechi_Iheanacho': 13,
#    'Alisson_Ramses_Becker': 9,
#    'Divock_Origi': 9,
#    'Kevin_De_Bruyne': 14,
#    'Sergio_Reguilon': 12,
#    'Japhet_Tanganga': 8,
#    'Aaron_Cresswell': 8,
#    'Pablo_Fornals': 14,
#    'Luke_Cundle': 11,
#    'Conor_Gallagher (C)': 30},
#   'bench': ['Cedric_Soares',
#    'David_Raya_Martin',
#    'Jamaal_Lascelles',
#    'HeeChan_Hwang'],
#   'total_points': 156},
#  4: {'line_up': {'Mateo_Kovacic': 13,
#    'Romelu_Lukaku': 13,
#    'Odsonne_Edouard': 12,
#    'Seamus_Coleman': 10,
#    'Kasper_Schmeichel': 9,
#    'Ricardo_Domingos_Barbosa_Pereira': 12,
#    'Mohamed_Salah': 17,
#    'Paul_Pogba': 16,
#    'Ryan_Fraser': 13,
#    'Eric_Dier': 12,
#    'Bruno_Miguel_Borges_Fernandes (C)': 40},
#   'bench': ['Hector_Bellerin',
#    'Pontus_Jansson',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 187},
#  5: {'line_up': {'Martin_degaard': 11,
#    'Aaron_Ramsdale': 9,
#    'Matthew_Cash': 15,
#    'Ivan_Toney': 12,
#    'Antonio_Rudiger': 14,
#    'Aymeric_Laporte': 14,
#    'Gabriel_Fernando_de_Jesus': 11,
#    'Oghenekaro_Peter_Etebo': 12,
#    'Ryan_Fredericks': 13,
#    'Declan_Rice': 12,
#    'Thiago_Emiliano_da_Silva (C)': 30},
#   'bench': ['Christian_Nrgaard',
#    'Saman_Ghoddos',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 168},
#  6: {'line_up': {'Emile_Smith_Rowe': 12,
#    'Bukayo_Saka': 13,
#    'Emiliano_Martinez': 9,
#    'Kortney_Hause': 15,
#    'Jamie_Vardy': 12,
#    'Gabriel_Fernando_de_Jesus': 12,
#    'Raphael_Varane': 12,
#    'Toby_Alderweireld': 11,
#    'Ryan_Fredericks': 16,
#    'Declan_Rice': 12,
#    'Ferran_Torres (C)': 36},
#   'bench': ['Pontus_Jansson', 'Saman_Ghoddos', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 178},
#  7: {'line_up': {'Trevoh_Chalobah': 11,
#    'Abdoulaye_Doucoure': 11,
#    'Andros_Townsend': 12,
#    'Alisson_Ramses_Becker': 9,
#    'Trent_AlexanderArnold': 12,
#    'Joao_Pedro_Cavaco_Cancelo': 12,
#    'Bernardo_Mota_Veiga_de_Carvalho_e_Silva': 10,
#    'Jeff_Hendrick': 9,
#    'Matt_Doherty': 10,
#    'Ryan_Fredericks': 11,
#    'Cristiano_Ronaldo_dos_Santos_Aveiro (C)': 26},
#   'bench': ['Edward_Nketiah', 'Saman_Ghoddos', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 146},
#  8: {'line_up': {'PierreEmerick_Aubameyang': 9,
#    'John_McGinn': 13,
#    'Lewis_Dunk': 9,
#    'Malang_Sarr': 8,
#    'Christian_Benteke': 9,
#    'Virgil_van_Dijk': 12,
#    'Mohamed_Salah': 12,
#    'David_de_Gea': 10,
#    'Aaron_Cresswell': 9,
#    'Leander_Dendoncker': 13,
#    'Benjamin_Chilwell (C)': 30},
#   'bench': ['Christian_Nrgaard',
#    'Tariqe_FosuHenry',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 149},
#  9: {'line_up': {'Emile_Smith_Rowe': 13,
#    'Emiliano_Martinez': 10,
#    'Maxwel_Cornet': 15,
#    'Benjamin_Chilwell': 12,
#    'Reece_James': 13,
#    'Andros_Townsend': 10,
#    'Jamie_Vardy': 11,
#    'Joao_Pedro_Cavaco_Cancelo': 12,
#    'Ben_Wilmot': 15,
#    'Declan_Rice': 10,
#    'Mason_Mount (C)': 48},
#   'bench': ['Edward_Nketiah',
#    'Pontus_Jansson',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 193},
#  10: {'line_up': {'Gabriel_Magalhaes': 15,
#    'Aaron_Ramsdale': 10,
#    'Matthew_Lowton': 14,
#    'Maxwel_Cornet': 10,
#    'Conor_Gallagher': 13,
#    'Andros_Townsend': 10,
#    'Kelechi_Iheanacho': 9,
#    'Diego_Llorente': 15,
#    'Mohamed_Salah': 13,
#    'Luke_Cundle': 14,
#    'Reece_James (C)': 42},
#   'bench': ['Edward_Nketiah',
#    'Calum_Chambers',
#    'David_Raya_Martin',
#    'HeeChan_Hwang'],
#   'total_points': 186},
#  11: {'line_up': {'Rico_Henry': 10,
#    'Leandro_Trossard': 10,
#    'Conor_Gallagher': 11,
#    'Mohamed_Salah': 13,
#    'Kevin_De_Bruyne': 11,
#    'Bernardo_Mota_Veiga_de_Carvalho_e_Silva': 11,
#    'Matt_Doherty': 10,
#    'Davinson_Sanchez': 10,
#    'Fernando_Marcal': 10,
#    'James_Storer': 13,
#    'Roberto_Firmino (C)': 40},
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Patrik_Gunnarsson',
#    'HeeChan_Hwang'],
#   'total_points': 169},
#  12: {'line_up': {'Tyrone_Mings': 15,
#    'Antonio_Rudiger': 14,
#    'Reece_James': 12,
#    'Christian_Benteke': 12,
#    'Naby_Keita': 13,
#    'Diogo_Jota': 11,
#    'Phil_Foden': 18,
#    'Serge_Aurier': 12,
#    'Darren_Randolph': 8,
#    'Aaron_Cresswell': 15,
#    'Mohamed_Salah (C)': 48},
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Solomon_March',
#    'Robert_Sanchez'],
#   'total_points': 202},
#  13: {'line_up': {'Nuno_Varela_Tavares': 11,
#    'Takehiro_Tomiyasu': 12,
#    'John_McGinn': 10,
#    'Alvaro_Fernandez': 9,
#    'Jordan_Henderson': 10,
#    'Cristiano_Ronaldo_dos_Santos_Aveiro': 12,
#    'Mohamed_Elyounoussi': 9,
#    'Oghenekaro_Peter_Etebo': 12,
#    'Winston_Reid': 9,
#    'Michail_Antonio': 12,
#    'Juan_Camilo_Hernandez_Suarez (C)': 32},
#   'bench': ['Rico_Henry', 'Charlie_Goode', 'Solomon_March', 'Robert_Sanchez'],
#   'total_points': 154},
#  14: {'line_up': {'Ollie_Watkins': 9,
#    'Mason_Mount': 12,
#    'Harvey_Barnes': 10,
#    'Raphael_Dias_Belloli': 9,
#    'Trent_AlexanderArnold': 12,
#    'Angus_Gunn': 10,
#    'Jan_Bednarek': 9,
#    'Tomas_Soucek': 11,
#    'Pablo_Fornals': 13,
#    'Fernando_Marcal': 9,
#    'Joao_Pedro_Cavaco_Cancelo (C)': 28},
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Charlie_Goode',
#    'Robert_Sanchez'],
#   'total_points': 146},
#  15: {'line_up': {'Kieran_Tierney': 12,
#    'Nick_Pope': 9,
#    'Mason_Mount': 13,
#    'Sadio_Mane': 12,
#    'Trent_AlexanderArnold': 15,
#    'Joao_Pedro_Cavaco_Cancelo': 12,
#    'Rodrigo_Hernandez': 10,
#    'Allan_SaintMaximin': 10,
#    'Dan_Gosling': 11,
#    'Ben_Johnson': 12,
#    'Ezri_Konsa_Ngoyo (C)': 34},
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Solomon_March',
#    'Robert_Sanchez'],
#   'total_points': 167},
#  16: {'line_up': {'Kieran_Tierney': 12,
#    'Gabriel_Magalhaes': 11,
#    'Aaron_Ramsdale': 11,
#    'Jorge_Luiz_Frello_Filho': 15,
#    'Conor_Gallagher': 15,
#    'Jamie_Vardy': 12,
#    'Virgil_van_Dijk': 15,
#    'Andrew_Robertson': 12,
#    'Diogo_Jota': 14,
#    'Oghenekaro_Peter_Etebo': 14,
#    'James_Maddison (C)': 32},
#   'bench': ['Ollie_Watkins',
#    'Wesley_Moraes',
#    'Charlie_Goode',
#    'Robert_Sanchez'],
#   'total_points': 179},
#  17: {'line_up': {'Ollie_Watkins': 12,
#    'Jacob_Ramsey': 10,
#    'Robert_Sanchez': 9,
#    'Marc_Cucurella': 9,
#    'Liam_Cooper': 12,
#    'Jordan_Henderson': 13,
#    'Ruben_Santos_Gato_Alves_Dias': 9,
#    'Cristiano_Ronaldo_dos_Santos_Aveiro': 13,
#    'Giovani_Lo_Celso': 12,
#    'Oghenekaro_Peter_Etebo': 10,
#    'Mohamed_Salah (C)': 30},
#   'bench': ['Folarin_Balogun', 'Rico_Henry', 'Charlie_Goode', 'Mathew_Ryan'],
#   'total_points': 154},
#  18: {'line_up': {'Nick_Pope': 10,
#    'Marcos_Alonso': 9,
#    'Bernardo_Mota_Veiga_de_Carvalho_e_Silva': 15,
#    'Frederico_Rodrigues_de_Paula_Santos': 11,
#    'Daniel_NLundulu': 10,
#    'Matt_Doherty': 13,
#    'Harry_Winks': 15,
#    'Steven_Bergwijn': 12,
#    'Issa_Diop': 9,
#    'Max_Kilman': 9,
#    'Gabriel_Teodoro_Martinelli_Silva (C)': 30},
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Mathew_Ryan',
#    'Dion_Sanderson'],
#   'total_points': 158},
#  19: {'line_up': {'Alexandre_Lacazette': 11,
#    'Kieran_Tierney': 13,
#    'Bukayo_Saka': 16,
#    'Mads_Roerslev_Rasmussen': 14,
#    'Alexis_Mac_Allister': 15,
#    'Jorge_Luiz_Frello_Filho': 15,
#    'Odsonne_Edouard': 14,
#    'James_Maddison': 16,
#    'David_de_Gea': 10,
#    'Vladimir_Coufal': 9,
#    'Youri_Tielemans (C)': 32},
#   'bench': ['Bjorn_Engels',
#    'Ellery_Balcombe',
#    'Rodrigo_Moreno',
#    'Dion_Sanderson'],
#   'total_points': 181},
#  20: {'line_up': {'Jacob_Ramsey': 12,
#    'Michael_Olise': 11,
#    'Jarrad_Branthwaite': 9,
#    'Kelechi_Iheanacho': 15,
#    'Trent_AlexanderArnold': 11,
#    'Kevin_De_Bruyne': 16,
#    'John_Stones': 12,
#    'Riyad_Mahrez': 13,
#    'Tobi_Omole': 11,
#    'Alphonse_Areola': 6,
#    'PierreEmile_Hjbjerg (C)': 34},
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Mathew_Ryan',
#    'Dion_Sanderson'],
#   'total_points': 167},
#  21: {'line_up': {'Lucas_Digne': 12,
#    'Adam_Webster': 11,
#    'Mateo_Kovacic': 10,
#    'Anthony_Gordon': 14,
#    'Kasper_Schmeichel': 15,
#    'Scott_McTominay': 12,
#    'Cristiano_Ronaldo_dos_Santos_Aveiro': 12,
#    'Shane_Long': 12,
#    'Winston_Reid': 11,
#    'Jonathan_Castro_Otto': 15,
#    'Joao_Pedro_Cavaco_Cancelo (C)': 36},
#   'bench': ['Folarin_Balogun',
#    'Conor_Hourihane',
#    'Bertrand_Traore',
#    'Mathew_Ryan'],
#   'total_points': 178},
#  22: {'line_up': {'Gabriel_Magalhaes': 14,
#    'Aaron_Ramsdale': 9,
#    'Jacob_Ramsey': 14,
#    'Connor_Roberts': 9,
#    'Wout_Weghorst': 12,
#    'Riyad_Mahrez': 10,
#    'Raheem_Sterling': 14,
#    'Aymeric_Laporte': 10,
#    'Kyle_WalkerPeters': 13,
#    'Steven_Bergwijn': 15,
#    'Philippe_Coutinho_Correia (C)': 32},
#   'bench': ['Folarin_Balogun',
#    'Ollie_Watkins',
#    'Charlie_Goode',
#    'Jonas_Lossl'],
#   'total_points': 168},
#  23: {'line_up': {'Emile_Smith_Rowe': 11,
#    'Adam_Webster': 15,
#    'Ben_Mee': 15,
#    'Seamus_Coleman': 14,
#    'Michael_Keane': 13,
#    'Patson_Daka': 9,
#    'Ederson_Santana_de_Moraes': 9,
#    'Bruno_Miguel_Borges_Fernandes': 14,
#    'Japhet_Tanganga': 13,
#    'Tomas_Soucek': 14,
#    'Jack_Harrison (C)': 40},
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Bertrand_Traore',
#    'Thomas_McGill'],
#   'total_points': 187},
#  24: {'line_up': {'Thiago_Emiliano_da_Silva': 13,
#    'Kepa_Arrizabalaga': 8,
#    'Hakim_Ziyech': 11,
#    'Fabio_Henrique_Tavares': 10,
#    'Andrew_Robertson': 12,
#    'Trent_AlexanderArnold': 10,
#    'Rodrigo_Hernandez': 9,
#    'Mason_Greenwood': 11,
#    'Moussa_Djenepo': 11,
#    'Patrick_Cutrone': 11,
#    'Vladimir_Coufal (C)': 30},
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Charlie_Goode',
#    'Thomas_McGill'],
#   'total_points': 151},
#  25: {'line_up': {'Bukayo_Saka': 12,
#    'Tyrone_Mings': 11,
#    'Matthew_Cash': 14,
#    'David_Raya_Martin': 10,
#    'Anthony_Gordon': 14,
#    'Daniel_James': 12,
#    'Matt_Ritchie': 11,
#    'Callum_Wilson': 9,
#    'Jarrod_Bowen': 11,
#    'Willy_Boly': 13,
#    'Tomas_Soucek (C)': 32},
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 165},
#  26: {'line_up': {'Thomas_Partey': 14,
#    'Aaron_Ramsdale': 9,
#    'Matthew_Cash': 11,
#    'Danny_Ings': 15,
#    'Kai_Havertz': 14,
#    'Wilfried_Zaha': 15,
#    'Joel_Matip': 11,
#    'Diogo_Jota': 16,
#    'Jamaal_Lascelles': 13,
#    'Christos_Tzolis': 13,
#    'Reece_James (C)': 36},
#   'bench': ['Edward_Nketiah',
#    'Calum_Chambers',
#    'David_Raya_Martin',
#    'HeeChan_Hwang'],
#   'total_points': 185},
#  27: {'line_up': {'Calum_Chambers': 14,
#    'Mason_Mount': 13,
#    'Kai_Havertz': 12,
#    'Jamie_Vardy': 11,
#    'Alisson_Ramses_Becker': 10,
#    'Kevin_De_Bruyne': 11,
#    'Kyle_WalkerPeters': 11,
#    'Serge_Aurier': 13,
#    'Alfie_Devine': 11,
#    'Ruben_Diogo_da_Silva_Neves': 14,
#    'Matthew_Cash (C)': 36},
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 174},
#  28: {'line_up': {'Bukayo_Saka': 11,
#    'Jacob_Ramsey': 10,
#    'Ivan_Toney': 17,
#    'Kristoffer_Ajer': 9,
#    'Trevoh_Chalobah': 9,
#    'Alex_Iwobi': 10,
#    'Kasper_Schmeichel': 10,
#    'Kyle_Walker': 10,
#    'Ruben_Santos_Gato_Alves_Dias': 10,
#    'Tomas_Soucek': 11,
#    'Raheem_Sterling (C)': 36},
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 161},
#  29: {'line_up': {'Ivan_Toney': 12,
#    'Vicente_Guaita': 9,
#    'Mohamed_Salah': 18,
#    'Andrew_Robertson': 13,
#    'Isaac_Hayden': 12,
#    'Mohamed_Elyounoussi': 12,
#    'Serge_Aurier': 11,
#    'Matt_Doherty': 9,
#    'Eric_Dier': 18,
#    'Tomas_Soucek': 13,
#    'Sadio_Mane (C)': 38},
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 184},
#  30: {'line_up': {'Timo_Werner': 15,
#    'Joachim_Andersen': 15,
#    'Richarlison_de_Andrade': 13,
#    'Asmir_Begovic': 11,
#    'Timothy_Castagne': 14,
#    'Jamaal_Lascelles': 13,
#    'Isaac_Hayden': 10,
#    'Nathan_Redmond': 10,
#    'Serge_Aurier': 13,
#    'Eric_Dier': 14,
#    'Mason_Mount (C)': 38},
#   'bench': ['Christian_Nrgaard',
#    'Tariqe_FosuHenry',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 185},
#  31: {'line_up': {'Vitaly_Janelt': 15,
#    'Enock_Mwepu': 14,
#    'Wout_Weghorst': 8,
#    'Jordan_Pickford': 9,
#    'Kelechi_Iheanacho': 8,
#    'Joel_Matip': 12,
#    'Riyad_Mahrez': 14,
#    'Danny_Rose': 7,
#    'Ozan_Tufan': 11,
#    'Issa_Diop': 11,
#    'Kevin_De_Bruyne (C)': 36},
#   'bench': ['Pontus_Jansson', 'Rico_Henry', 'Jason_Steele', 'HeeChan_Hwang'],
#   'total_points': 163},
#  32: {'line_up': {'Edward_Nketiah': 13,
#    'Ivan_Toney': 12,
#    'Bryan_Mbeumo': 13,
#    'Leandro_Trossard': 11,
#    'Nathan_Collins': 13,
#    'Connor_Roberts': 15,
#    'Kasper_Schmeichel': 9,
#    'Kiernan_DewsburyHall': 13,
#    'Andrew_Robertson': 12,
#    'Emerson_Aparecido_Leite_de_Souza_Junior': 14,
#    'Cristiano_Ronaldo_dos_Santos_Aveiro (C)': 34},
#   'bench': ['Mohamed_Naser_El_Sayed_Elneny',
#    'Thomas_Partey',
#    'Viljami_Sinisalo',
#    'Rico_Henry'],
#   'total_points': 176},
#  33: {'line_up': {'Bukayo_Saka': 13,
#    'Ollie_Watkins': 9,
#    'Nick_Pope': 10,
#    'Luke_Ayling': 13,
#    'Diogo_Jota': 14,
#    'Raheem_Sterling': 11,
#    'Serge_Aurier': 13,
#    'Ozan_Tufan': 12,
#    'Declan_Rice': 11,
#    'Romain_Saiss': 14,
#    'Matt_Doherty (C)': 30},
#   'bench': ['Edward_Nketiah', 'Charlie_Goode', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 165},
#  34: {'line_up': {'Rob_Holding': 10,
#    'Gabriel_Magalhaes': 11,
#    'Jack_Cork': 10,
#    'Josh_Brownhill': 10,
#    'Harvey_Barnes': 11,
#    'Teemu_Pukki': 10,
#    'Kyle_WalkerPeters': 10,
#    'Matt_Doherty': 12,
#    'Eric_Dier': 14,
#    'Jose_Malheiro_de_Sa': 12,
#    'Emiliano_Buendia_Stati (C)': 28},
#   'bench': ['Thomas_Partey', 'Ollie_Watkins', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 152},
#  35: {'line_up': {'Edward_Nketiah': 13,
#    'Romelu_Lukaku': 13,
#    'Kasper_Schmeichel': 8,
#    'Mohamed_Salah': 19,
#    'Luis_Diaz': 12,
#    'Riyad_Mahrez': 14,
#    'Cristiano_Ronaldo_dos_Santos_Aveiro': 17,
#    'Toby_Alderweireld': 10,
#    'Serge_Aurier': 10,
#    'Tomas_Soucek': 13,
#    'Matt_Doherty (C)': 42},
#   'bench': ['Jason_Steele',
#    'Martin_Kelly',
#    'Fabian_Delph',
#    'Konstantinos_Tsimikas'],
#   'total_points': 192},
#  36: {'line_up': {'Pontus_Jansson': 15,
#    'Kristoffer_Ajer': 14,
#    'Pascal_Gro': 13,
#    'Leandro_Trossard': 17,
#    'Mason_Mount': 13,
#    'Reece_James': 12,
#    'Illan_Meslier': 11,
#    'Andrew_Robertson': 15,
#    'Lucas_De_Bolle': 14,
#    'Daniel_NLundulu': 15,
#    'Gabriel_Fernando_de_Jesus (C)': 48},
#   'bench': ['Folarin_Balogun',
#    'Jed_Steer',
#    'Rico_Henry',
#    'Bruno_Andre_Cavaco_Jordao'],
#   'total_points': 211},
#  37: {'line_up': {'Yoane_Wissa': 11,
#    'Marcos_Alonso': 9,
#    'Patson_Daka': 9,
#    'Alisson_Ramses_Becker': 9,
#    'Naby_Keita': 10,
#    'Ruben_Santos_Gato_Alves_Dias': 12,
#    'Phil_Foden': 9,
#    'Rodrigo_Hernandez': 9,
#    'Emerson_Aparecido_Leite_de_Souza_Junior': 9,
#    'Issa_Diop': 10,
#    'Richarlison_de_Andrade (C)': 24},
#   'bench': ['Folarin_Balogun',
#    'Jed_Steer',
#    'Kortney_Hause',
#    'Bruno_Andre_Cavaco_Jordao'],
#   'total_points': 133},
#  38: {'line_up': {'Cedric_Soares': 14,
#    'Gabriel_Teodoro_Martinelli_Silva': 12,
#    'Pascal_Gro': 13,
#    'Danny_Welbeck': 11,
#    'Vicente_Guaita': 10,
#    'Jamie_Vardy': 13,
#    'Raheem_Sterling': 16,
#    'Aymeric_Laporte': 12,
#    'Jamal_Lewis': 13,
#    'Kyle_WalkerPeters': 15,
#    'Matt_Doherty (C)': 38},
#   'bench': ['Folarin_Balogun',
#    'Conor_Hourihane',
#    'Bertrand_Traore',
#    'David_Raya_Martin'],
#   'total_points': 186}}

# %%
total_points = 0
for gw in team.values():
    total_points += gw["total_points"]
total_points
# Out:
# 6539

# %%
objective_value
# Out:
# 5869

# %%
(total_points - objective_value) / 4
# Out:
# 167.5

# %%
team
# Out:
# {1: {'line_up': ['Sergi_Canos',
#    'Ethan_Pinnock',
#    'Marcos_Alonso',
#    'Trevoh_Chalobah',
#    'Dennis_Praet',
#    'Kelechi_Iheanacho',
#    'Wilfred_Ndidi',
#    'Thiago_Alcantara_do_Nascimento',
#    'Dean_Henderson',
#    'Cristiano_Ronaldo_dos_Santos_Aveiro',
#    'John_Stones (C)'],
#   'bench': ['Hector_Bellerin',
#    'Saman_Ghoddos',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 180},
#  2: {'line_up': ['Tyrone_Mings',
#    'Shane_Duffy',
#    'Vicente_Guaita',
#    'Richarlison_de_Andrade',
#    'Thiago_Alcantara_do_Nascimento',
#    'HeungMin_Son',
#    'Eric_Dier',
#    'Craig_Cathcart',
#    'Tomas_Soucek',
#    'Pablo_Fornals',
#    'Reece_James (C)'],
#   'bench': ['Edward_Nketiah', 'Saman_Ghoddos', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 161},
#  3: {'line_up': ['James_Maddison',
#    'Kelechi_Iheanacho',
#    'Alisson_Ramses_Becker',
#    'Divock_Origi',
#    'Kevin_De_Bruyne',
#    'Sergio_Reguilon',
#    'Japhet_Tanganga',
#    'Aaron_Cresswell',
#    'Pablo_Fornals',
#    'Luke_Cundle',
#    'Conor_Gallagher (C)'],
#   'bench': ['Cedric_Soares',
#    'David_Raya_Martin',
#    'Jamaal_Lascelles',
#    'HeeChan_Hwang'],
#   'total_points': 141},
#  4: {'line_up': ['Mateo_Kovacic',
#    'Romelu_Lukaku',
#    'Odsonne_Edouard',
#    'Seamus_Coleman',
#    'Kasper_Schmeichel',
#    'Ricardo_Domingos_Barbosa_Pereira',
#    'Mohamed_Salah',
#    'Paul_Pogba',
#    'Ryan_Fraser',
#    'Eric_Dier',
#    'Bruno_Miguel_Borges_Fernandes (C)'],
#   'bench': ['Hector_Bellerin',
#    'Pontus_Jansson',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 167},
#  5: {'line_up': ['Martin_degaard',
#    'Aaron_Ramsdale',
#    'Matthew_Cash',
#    'Ivan_Toney',
#    'Antonio_Rudiger',
#    'Aymeric_Laporte',
#    'Gabriel_Fernando_de_Jesus',
#    'Oghenekaro_Peter_Etebo',
#    'Ryan_Fredericks',
#    'Declan_Rice',
#    'Thiago_Emiliano_da_Silva (C)'],
#   'bench': ['Christian_Nrgaard',
#    'Saman_Ghoddos',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 153},
#  6: {'line_up': ['Emile_Smith_Rowe',
#    'Bukayo_Saka',
#    'Emiliano_Martinez',
#    'Kortney_Hause',
#    'Jamie_Vardy',
#    'Gabriel_Fernando_de_Jesus',
#    'Raphael_Varane',
#    'Toby_Alderweireld',
#    'Ryan_Fredericks',
#    'Declan_Rice',
#    'Ferran_Torres (C)'],
#   'bench': ['Pontus_Jansson', 'Saman_Ghoddos', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 160},
#  7: {'line_up': ['Trevoh_Chalobah',
#    'Abdoulaye_Doucoure',
#    'Andros_Townsend',
#    'Alisson_Ramses_Becker',
#    'Trent_AlexanderArnold',
#    'Joao_Pedro_Cavaco_Cancelo',
#    'Bernardo_Mota_Veiga_de_Carvalho_e_Silva',
#    'Jeff_Hendrick',
#    'Matt_Doherty',
#    'Ryan_Fredericks',
#    'Cristiano_Ronaldo_dos_Santos_Aveiro (C)'],
#   'bench': ['Edward_Nketiah', 'Saman_Ghoddos', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 133},
#  8: {'line_up': ['PierreEmerick_Aubameyang',
#    'John_McGinn',
#    'Lewis_Dunk',
#    'Malang_Sarr',
#    'Christian_Benteke',
#    'Virgil_van_Dijk',
#    'Mohamed_Salah',
#    'David_de_Gea',
#    'Aaron_Cresswell',
#    'Leander_Dendoncker',
#    'Benjamin_Chilwell (C)'],
#   'bench': ['Christian_Nrgaard',
#    'Tariqe_FosuHenry',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 134},
#  9: {'line_up': ['Emile_Smith_Rowe',
#    'Emiliano_Martinez',
#    'Maxwel_Cornet',
#    'Benjamin_Chilwell',
#    'Reece_James',
#    'Andros_Townsend',
#    'Jamie_Vardy',
#    'Joao_Pedro_Cavaco_Cancelo',
#    'Ben_Wilmot',
#    'Declan_Rice',
#    'Mason_Mount (C)'],
#   'bench': ['Edward_Nketiah',
#    'Pontus_Jansson',
#    'Mathew_Ryan',
#    'HeeChan_Hwang'],
#   'total_points': 169},
#  10: {'line_up': ['Gabriel_Magalhaes',
#    'Aaron_Ramsdale',
#    'Matthew_Lowton',
#    'Maxwel_Cornet',
#    'Conor_Gallagher',
#    'Andros_Townsend',
#    'Kelechi_Iheanacho',
#    'Diego_Llorente',
#    'Mohamed_Salah',
#    'Luke_Cundle',
#    'Reece_James (C)'],
#   'bench': ['Edward_Nketiah',
#    'Calum_Chambers',
#    'David_Raya_Martin',
#    'HeeChan_Hwang'],
#   'total_points': 165},
#  11: {'line_up': ['Rico_Henry',
#    'Leandro_Trossard',
#    'Conor_Gallagher',
#    'Mohamed_Salah',
#    'Kevin_De_Bruyne',
#    'Bernardo_Mota_Veiga_de_Carvalho_e_Silva',
#    'Matt_Doherty',
#    'Davinson_Sanchez',
#    'Fernando_Marcal',
#    'James_Storer',
#    'Roberto_Firmino (C)'],
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Patrik_Gunnarsson',
#    'HeeChan_Hwang'],
#   'total_points': 149},
#  12: {'line_up': ['Tyrone_Mings',
#    'Antonio_Rudiger',
#    'Reece_James',
#    'Christian_Benteke',
#    'Naby_Keita',
#    'Diogo_Jota',
#    'Phil_Foden',
#    'Serge_Aurier',
#    'Darren_Randolph',
#    'Aaron_Cresswell',
#    'Mohamed_Salah (C)'],
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Solomon_March',
#    'Robert_Sanchez'],
#   'total_points': 178},
#  13: {'line_up': ['Nuno_Varela_Tavares',
#    'Takehiro_Tomiyasu',
#    'John_McGinn',
#    'Alvaro_Fernandez',
#    'Jordan_Henderson',
#    'Cristiano_Ronaldo_dos_Santos_Aveiro',
#    'Mohamed_Elyounoussi',
#    'Oghenekaro_Peter_Etebo',
#    'Winston_Reid',
#    'Michail_Antonio',
#    'Juan_Camilo_Hernandez_Suarez (C)'],
#   'bench': ['Rico_Henry', 'Charlie_Goode', 'Solomon_March', 'Robert_Sanchez'],
#   'total_points': 138},
#  14: {'line_up': ['Ollie_Watkins',
#    'Mason_Mount',
#    'Harvey_Barnes',
#    'Raphael_Dias_Belloli',
#    'Trent_AlexanderArnold',
#    'Angus_Gunn',
#    'Jan_Bednarek',
#    'Tomas_Soucek',
#    'Pablo_Fornals',
#    'Fernando_Marcal',
#    'Joao_Pedro_Cavaco_Cancelo (C)'],
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Charlie_Goode',
#    'Robert_Sanchez'],
#   'total_points': 132},
#  15: {'line_up': ['Kieran_Tierney',
#    'Nick_Pope',
#    'Mason_Mount',
#    'Sadio_Mane',
#    'Trent_AlexanderArnold',
#    'Joao_Pedro_Cavaco_Cancelo',
#    'Rodrigo_Hernandez',
#    'Allan_SaintMaximin',
#    'Dan_Gosling',
#    'Ben_Johnson',
#    'Ezri_Konsa_Ngoyo (C)'],
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Solomon_March',
#    'Robert_Sanchez'],
#   'total_points': 150},
#  16: {'line_up': ['Kieran_Tierney',
#    'Gabriel_Magalhaes',
#    'Aaron_Ramsdale',
#    'Jorge_Luiz_Frello_Filho',
#    'Conor_Gallagher',
#    'Jamie_Vardy',
#    'Virgil_van_Dijk',
#    'Andrew_Robertson',
#    'Diogo_Jota',
#    'Oghenekaro_Peter_Etebo',
#    'James_Maddison (C)'],
#   'bench': ['Ollie_Watkins',
#    'Wesley_Moraes',
#    'Charlie_Goode',
#    'Robert_Sanchez'],
#   'total_points': 163},
#  17: {'line_up': ['Ollie_Watkins',
#    'Jacob_Ramsey',
#    'Robert_Sanchez',
#    'Marc_Cucurella',
#    'Liam_Cooper',
#    'Jordan_Henderson',
#    'Ruben_Santos_Gato_Alves_Dias',
#    'Cristiano_Ronaldo_dos_Santos_Aveiro',
#    'Giovani_Lo_Celso',
#    'Oghenekaro_Peter_Etebo',
#    'Mohamed_Salah (C)'],
#   'bench': ['Folarin_Balogun', 'Rico_Henry', 'Charlie_Goode', 'Mathew_Ryan'],
#   'total_points': 139},
#  18: {'line_up': ['Nick_Pope',
#    'Marcos_Alonso',
#    'Bernardo_Mota_Veiga_de_Carvalho_e_Silva',
#    'Frederico_Rodrigues_de_Paula_Santos',
#    'Daniel_NLundulu',
#    'Matt_Doherty',
#    'Harry_Winks',
#    'Steven_Bergwijn',
#    'Issa_Diop',
#    'Max_Kilman',
#    'Gabriel_Teodoro_Martinelli_Silva (C)'],
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Mathew_Ryan',
#    'Dion_Sanderson'],
#   'total_points': 143},
#  19: {'line_up': ['Alexandre_Lacazette',
#    'Kieran_Tierney',
#    'Bukayo_Saka',
#    'Mads_Roerslev_Rasmussen',
#    'Alexis_Mac_Allister',
#    'Jorge_Luiz_Frello_Filho',
#    'Odsonne_Edouard',
#    'James_Maddison',
#    'David_de_Gea',
#    'Vladimir_Coufal',
#    'Youri_Tielemans (C)'],
#   'bench': ['Bjorn_Engels',
#    'Ellery_Balcombe',
#    'Rodrigo_Moreno',
#    'Dion_Sanderson'],
#   'total_points': 165},
#  20: {'line_up': ['Jacob_Ramsey',
#    'Michael_Olise',
#    'Jarrad_Branthwaite',
#    'Kelechi_Iheanacho',
#    'Trent_AlexanderArnold',
#    'Kevin_De_Bruyne',
#    'John_Stones',
#    'Riyad_Mahrez',
#    'Tobi_Omole',
#    'Alphonse_Areola',
#    'PierreEmile_Hjbjerg (C)'],
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Mathew_Ryan',
#    'Dion_Sanderson'],
#   'total_points': 150},
#  21: {'line_up': ['Lucas_Digne',
#    'Adam_Webster',
#    'Mateo_Kovacic',
#    'Anthony_Gordon',
#    'Kasper_Schmeichel',
#    'Scott_McTominay',
#    'Cristiano_Ronaldo_dos_Santos_Aveiro',
#    'Shane_Long',
#    'Winston_Reid',
#    'Jonathan_Castro_Otto',
#    'Joao_Pedro_Cavaco_Cancelo (C)'],
#   'bench': ['Folarin_Balogun',
#    'Conor_Hourihane',
#    'Bertrand_Traore',
#    'Mathew_Ryan'],
#   'total_points': 160},
#  22: {'line_up': ['Gabriel_Magalhaes',
#    'Aaron_Ramsdale',
#    'Jacob_Ramsey',
#    'Connor_Roberts',
#    'Wout_Weghorst',
#    'Riyad_Mahrez',
#    'Raheem_Sterling',
#    'Aymeric_Laporte',
#    'Kyle_WalkerPeters',
#    'Steven_Bergwijn',
#    'Philippe_Coutinho_Correia (C)'],
#   'bench': ['Folarin_Balogun',
#    'Ollie_Watkins',
#    'Charlie_Goode',
#    'Jonas_Lossl'],
#   'total_points': 152},
#  23: {'line_up': ['Emile_Smith_Rowe',
#    'Adam_Webster',
#    'Ben_Mee',
#    'Seamus_Coleman',
#    'Michael_Keane',
#    'Patson_Daka',
#    'Ederson_Santana_de_Moraes',
#    'Bruno_Miguel_Borges_Fernandes',
#    'Japhet_Tanganga',
#    'Tomas_Soucek',
#    'Jack_Harrison (C)'],
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Bertrand_Traore',
#    'Thomas_McGill'],
#   'total_points': 167},
#  24: {'line_up': ['Thiago_Emiliano_da_Silva',
#    'Kepa_Arrizabalaga',
#    'Hakim_Ziyech',
#    'Fabio_Henrique_Tavares',
#    'Andrew_Robertson',
#    'Trent_AlexanderArnold',
#    'Rodrigo_Hernandez',
#    'Mason_Greenwood',
#    'Moussa_Djenepo',
#    'Patrick_Cutrone',
#    'Vladimir_Coufal (C)'],
#   'bench': ['Edward_Nketiah',
#    'Folarin_Balogun',
#    'Charlie_Goode',
#    'Thomas_McGill'],
#   'total_points': 136},
#  25: {'line_up': ['Bukayo_Saka',
#    'Tyrone_Mings',
#    'Matthew_Cash',
#    'David_Raya_Martin',
#    'Anthony_Gordon',
#    'Daniel_James',
#    'Matt_Ritchie',
#    'Callum_Wilson',
#    'Jarrod_Bowen',
#    'Willy_Boly',
#    'Tomas_Soucek (C)'],
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 149},
#  26: {'line_up': ['Thomas_Partey',
#    'Aaron_Ramsdale',
#    'Matthew_Cash',
#    'Danny_Ings',
#    'Kai_Havertz',
#    'Wilfried_Zaha',
#    'Joel_Matip',
#    'Diogo_Jota',
#    'Jamaal_Lascelles',
#    'Christos_Tzolis',
#    'Reece_James (C)'],
#   'bench': ['Edward_Nketiah',
#    'Calum_Chambers',
#    'David_Raya_Martin',
#    'HeeChan_Hwang'],
#   'total_points': 167},
#  27: {'line_up': ['Calum_Chambers',
#    'Mason_Mount',
#    'Kai_Havertz',
#    'Jamie_Vardy',
#    'Alisson_Ramses_Becker',
#    'Kevin_De_Bruyne',
#    'Kyle_WalkerPeters',
#    'Serge_Aurier',
#    'Alfie_Devine',
#    'Ruben_Diogo_da_Silva_Neves',
#    'Matthew_Cash (C)'],
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 156},
#  28: {'line_up': ['Bukayo_Saka',
#    'Jacob_Ramsey',
#    'Ivan_Toney',
#    'Kristoffer_Ajer',
#    'Trevoh_Chalobah',
#    'Alex_Iwobi',
#    'Kasper_Schmeichel',
#    'Kyle_Walker',
#    'Ruben_Santos_Gato_Alves_Dias',
#    'Tomas_Soucek',
#    'Raheem_Sterling (C)'],
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 143},
#  29: {'line_up': ['Ivan_Toney',
#    'Vicente_Guaita',
#    'Mohamed_Salah',
#    'Andrew_Robertson',
#    'Isaac_Hayden',
#    'Mohamed_Elyounoussi',
#    'Serge_Aurier',
#    'Matt_Doherty',
#    'Eric_Dier',
#    'Tomas_Soucek',
#    'Sadio_Mane (C)'],
#   'bench': ['Edward_Nketiah',
#    'Charlie_Goode',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 165},
#  30: {'line_up': ['Timo_Werner',
#    'Joachim_Andersen',
#    'Richarlison_de_Andrade',
#    'Asmir_Begovic',
#    'Timothy_Castagne',
#    'Jamaal_Lascelles',
#    'Isaac_Hayden',
#    'Nathan_Redmond',
#    'Serge_Aurier',
#    'Eric_Dier',
#    'Mason_Mount (C)'],
#   'bench': ['Christian_Nrgaard',
#    'Tariqe_FosuHenry',
#    'Thomas_McGill',
#    'HeeChan_Hwang'],
#   'total_points': 166},
#  31: {'line_up': ['Vitaly_Janelt',
#    'Enock_Mwepu',
#    'Wout_Weghorst',
#    'Jordan_Pickford',
#    'Kelechi_Iheanacho',
#    'Joel_Matip',
#    'Riyad_Mahrez',
#    'Danny_Rose',
#    'Ozan_Tufan',
#    'Issa_Diop',
#    'Kevin_De_Bruyne (C)'],
#   'bench': ['Pontus_Jansson', 'Rico_Henry', 'Jason_Steele', 'HeeChan_Hwang'],
#   'total_points': 145},
#  32: {'line_up': ['Edward_Nketiah',
#    'Ivan_Toney',
#    'Bryan_Mbeumo',
#    'Leandro_Trossard',
#    'Nathan_Collins',
#    'Connor_Roberts',
#    'Kasper_Schmeichel',
#    'Kiernan_DewsburyHall',
#    'Andrew_Robertson',
#    'Emerson_Aparecido_Leite_de_Souza_Junior',
#    'Cristiano_Ronaldo_dos_Santos_Aveiro (C)'],
#   'bench': ['Mohamed_Naser_El_Sayed_Elneny',
#    'Thomas_Partey',
#    'Viljami_Sinisalo',
#    'Rico_Henry'],
#   'total_points': 159},
#  33: {'line_up': ['Bukayo_Saka',
#    'Ollie_Watkins',
#    'Nick_Pope',
#    'Luke_Ayling',
#    'Diogo_Jota',
#    'Raheem_Sterling',
#    'Serge_Aurier',
#    'Ozan_Tufan',
#    'Declan_Rice',
#    'Romain_Saiss',
#    'Matt_Doherty (C)'],
#   'bench': ['Edward_Nketiah', 'Charlie_Goode', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 150},
#  34: {'line_up': ['Rob_Holding',
#    'Gabriel_Magalhaes',
#    'Jack_Cork',
#    'Josh_Brownhill',
#    'Harvey_Barnes',
#    'Teemu_Pukki',
#    'Kyle_WalkerPeters',
#    'Matt_Doherty',
#    'Eric_Dier',
#    'Jose_Malheiro_de_Sa',
#    'Emiliano_Buendia_Stati (C)'],
#   'bench': ['Thomas_Partey', 'Ollie_Watkins', 'Mathew_Ryan', 'HeeChan_Hwang'],
#   'total_points': 138},
#  35: {'line_up': ['Edward_Nketiah',
#    'Romelu_Lukaku',
#    'Kasper_Schmeichel',
#    'Mohamed_Salah',
#    'Luis_Diaz',
#    'Riyad_Mahrez',
#    'Cristiano_Ronaldo_dos_Santos_Aveiro',
#    'Toby_Alderweireld',
#    'Serge_Aurier',
#    'Tomas_Soucek',
#    'Matt_Doherty (C)'],
#   'bench': ['Jason_Steele',
#    'Martin_Kelly',
#    'Fabian_Delph',
#    'Konstantinos_Tsimikas'],
#   'total_points': 171},
#  36: {'line_up': ['Pontus_Jansson',
#    'Kristoffer_Ajer',
#    'Pascal_Gro',
#    'Leandro_Trossard',
#    'Mason_Mount',
#    'Reece_James',
#    'Illan_Meslier',
#    'Andrew_Robertson',
#    'Lucas_De_Bolle',
#    'Daniel_NLundulu',
#    'Gabriel_Fernando_de_Jesus (C)'],
#   'bench': ['Folarin_Balogun',
#    'Jed_Steer',
#    'Rico_Henry',
#    'Bruno_Andre_Cavaco_Jordao'],
#   'total_points': 187},
#  37: {'line_up': ['Yoane_Wissa',
#    'Marcos_Alonso',
#    'Patson_Daka',
#    'Alisson_Ramses_Becker',
#    'Naby_Keita',
#    'Ruben_Santos_Gato_Alves_Dias',
#    'Phil_Foden',
#    'Rodrigo_Hernandez',
#    'Emerson_Aparecido_Leite_de_Souza_Junior',
#    'Issa_Diop',
#    'Richarlison_de_Andrade (C)'],
#   'bench': ['Folarin_Balogun',
#    'Jed_Steer',
#    'Kortney_Hause',
#    'Bruno_Andre_Cavaco_Jordao'],
#   'total_points': 121},
#  38: {'line_up': ['Cedric_Soares',
#    'Gabriel_Teodoro_Martinelli_Silva',
#    'Pascal_Gro',
#    'Danny_Welbeck',
#    'Vicente_Guaita',
#    'Jamie_Vardy',
#    'Raheem_Sterling',
#    'Aymeric_Laporte',
#    'Jamal_Lewis',
#    'Kyle_WalkerPeters',
#    'Matt_Doherty (C)'],
#   'bench': ['Folarin_Balogun',
#    'Conor_Hourihane',
#    'Bertrand_Traore',
#    'David_Raya_Martin'],
#   'total_points': 167}}
